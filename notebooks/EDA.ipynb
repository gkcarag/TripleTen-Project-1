# %% [markdown]
# I'm going to be organizing the data set, which includes

# %%
import pandas as pd
import streamlit
import plotly.express
import altair

# %%
df = pd.read_csv('../vehicles_us.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    47906 non-null  float64
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     46265 non-null  float64
#  5   fuel          51525 non-null  object
#  6   odometer      43633 non-null  float64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   42258 non-null  object
#  10  is_4wd        25572 non-null  float64
#  11  date_posted   51525 non-null  object
#  12  days_listed   51525 non-null  int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 5.1+ MB

# %% [markdown]
# 'model_year', 'cylinders', 'odometer', 'paint_color', and 'is4wd' have null values.

# %%
df.sample(10, random_state=1)
# Out:
#        price  model_year                       model  condition  cylinders  \
# 26221   9995      2013.0              ford fusion se  excellent        4.0
# 48959  17995      2014.0                  gmc acadia  excellent        6.0
# 46104   8081      2006.0                  ford f-150  excellent        8.0
# 27780   3995      2006.0             chevrolet tahoe       good        8.0
# 5378    1990      2004.0                  ford focus   like new        4.0
# 43576   1150      2000.0  jeep grand cherokee laredo       fair        NaN
# 43436  19995      2014.0    chevrolet silverado 1500  excellent        NaN
# 36119   6900      2000.0               toyota tundra   like new        8.0
# 5044    8995      2011.0                   gmc yukon  excellent        8.0
# 23465   7995      2007.0                    ram 1500   like new        8.0
#
#       fuel  odometer transmission       type paint_color  is_4wd date_posted  \
# ...

# %% [markdown]
# 'is_4wd' has null values, and should be a boolean data type

# %%
# Fill na values with 0 to indicate not 4wd
df['is_4wd'] = df['is_4wd'].fillna(0)

# replace datatype with bool, to change 1 and 0 to T and F
df['is_4wd'] = df['is_4wd'].astype('bool')
df.sample(10, random_state=1)
# Out:
#        price  model_year                       model  condition  cylinders  \
# 26221   9995      2013.0              ford fusion se  excellent        4.0
# 48959  17995      2014.0                  gmc acadia  excellent        6.0
# 46104   8081      2006.0                  ford f-150  excellent        8.0
# 27780   3995      2006.0             chevrolet tahoe       good        8.0
# 5378    1990      2004.0                  ford focus   like new        4.0
# 43576   1150      2000.0  jeep grand cherokee laredo       fair        NaN
# 43436  19995      2014.0    chevrolet silverado 1500  excellent        NaN
# 36119   6900      2000.0               toyota tundra   like new        8.0
# 5044    8995      2011.0                   gmc yukon  excellent        8.0
# 23465   7995      2007.0                    ram 1500   like new        8.0
#
#       fuel  odometer transmission       type paint_color  is_4wd date_posted  \
# ...
